# %%
import torch

from modules import Transformer

# %%
model = Transformer(input_dim=384, hidden_dim=384, output_dim=384, depth=6, heads=16, dim_head=64, mlp_dim=2048, dropout=0.1)

# %%
model
# Out:
# Transformer(
#   (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True, bias=True)
#   (layers): ModuleList(
#     (0-5): 6 x Block(
#       (attn): Attention(
#         (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True, bias=True)
#         (attend): Softmax(dim=-1)
#         (to_qkv): Linear(in_features=384, out_features=3072, bias=False)
#         (to_out): Sequential(
#           (0): Linear(in_features=1024, out_features=384, bias=True)
#           (1): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (mlp): FeedForward(
#         (net): Sequential(
#           (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True, bias=True)
#           (1): Linear(in_features=384, out_features=2048, bias=True)
#           (2): GELU(approximate='none')
#           (3): Dropout(p=0.1, inplace=False)
#           (4): Linear(in_features=2048, out_features=384, bias=True)
#           (5): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=False, bias=False)
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=False, bias=False)
#     )
#   )
#   (input_proj): Identity()
#   (cond_proj): Identity()
#   (output_proj): Identity()
# )
